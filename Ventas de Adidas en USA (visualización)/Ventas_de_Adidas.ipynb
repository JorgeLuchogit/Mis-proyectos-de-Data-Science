# %% [markdown]
# # Analysis of Adidas sales in the USA data
#
# ### This ipybn file contains a brief revision of an Adidas sales in the  USA dataset, containing sales records from 2020 to 2021.
#
# Reference: This dataset was obtained from Kaggle at https://www.kaggle.com/datasets/sagarmorework/adidas-us-sales.
#
# After to start with data manipulation a fast view of the file in Excel was made, and was found that dataset counts with a 4 rows header and 14 fields, being the first a completely empty field. No footer was found.
#
# Once saw that, we start with data manipulation:

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import sys

# %%
# Import data
df= pd.read_excel('AdidasUSSalesDatasets.xlsx', skiprows=4, usecols=[i+1 for i in range(13)])

# %% [markdown]
# ## 1. First visualization
#
# We observe the firs basic aspects:

# %%
# First rows:
df.head(3)
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
#
#                    Product  Price per Unit  Units Sold  Total Sales  \
# 0    Men's Street Footwear            50.0        1200     600000.0
# 1  Men's Athletic Footwear            50.0        1000     500000.0
# 2  Women's Street Footwear            40.0        1000     400000.0
#
#    Operating Profit  Operating Margin Sales Method
# 0          300000.0              0.50     In-store
# 1          150000.0              0.30     In-store
# 2          140000.0              0.35     In-store

# %%
# null and nan values:
df.isnull().describe()
df.isna().describe()
# Out:
#        Retailer Retailer ID Invoice Date Region  State   City Product  \
# count      9648        9648         9648   9648   9648   9648    9648
# unique        1           1            1      1      1      1       1
# top       False       False        False  False  False  False   False
# freq       9648        9648         9648   9648   9648   9648    9648
#
#        Price per Unit Units Sold Total Sales Operating Profit  \
# count            9648       9648        9648             9648
# unique              1          1           1                1
# top             False      False       False            False
# freq             9648       9648        9648             9648
#
#        Operating Margin Sales Method
# count              9648         9648
# unique                1            1
# top               False        False
# freq               9648         9648

# %% [markdown]
# *df* does not contain **nan** nor **null** values.  Now we observe the dtypes compounding *df* $df$:

# %%
df.dtypes
# Out:
# Retailer                    object
# Retailer ID                  int64
# Invoice Date        datetime64[ns]
# Region                      object
# State                       object
# City                        object
# Product                     object
# Price per Unit             float64
# Units Sold                   int64
# Total Sales                float64
# Operating Profit           float64
# Operating Margin           float64
# Sales Method                object
# dtype: object

# %% [markdown]
# And apparently everything is ok with the dataset.

# %%
df.groupby(['State']).sum('Total Sales')
# Out:
#                 Retailer ID  Price per Unit  Units Sold  Total Sales  \
# State
# Alabama           258586308          7924.0       63327   17633424.0
# Alaska            169711614          8239.0       30815   14753103.0
# Arizona           243712584          9928.0       46919   15782221.0
# Arkansas          258731496          7201.0       48468   12639347.0
# California        501405708         21404.0      163284   60174133.0
# Colorado          162475056          8653.0       41378   20996536.0
# Connecticut       256118112          9421.0       34696   11573448.0
# Delaware          170745408          6827.0       30275   12298412.0
# Florida           416008683         20410.0      133430   59283714.0
# Georgia           245263275         10110.0       56391   18997466.0
# Hawaii            162475056          9252.0       40375   22282457.0
# Idaho             256854132          8643.0       63827   19276878.0
# ...
